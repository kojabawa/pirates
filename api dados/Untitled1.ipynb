# %%
import pandas as pd

# %%
pd.read_pickle('dados_bitcoin')
# Out:
#                                                       body  \
# 1469828  Of course, i completely agree, but it's undeni...
# 1469827  lol\n\nso the satellites can be taken out by a...
# 1469826                         Ok if you say so lasagna85
# 1469825  &gt;In that Google is hostile to bitcoin and f...
# 1469824  Or you could answer the question in order to b...
# ...                                                    ...
# 4        It's easier if you stretch it over a broomstic...
# 3               Today he is all of our Dearest Grandpapa 😀
# 2        Exodus is close source. You already lost a lot...
# 1        My apologies. I didn't count right. Should be ...
# 0        As long as I store all my coins on trezor, it ...
#
#                 created_utc  score  TBPolarity  TBSubjectivity
# 1469828 2019-01-01 03:02:36      1   -0.251852        0.296296
# 1469827 2019-01-01 03:08:48      1    0.800000        0.700000
# 1469826 2019-01-01 03:09:04      1    0.500000        0.500000
# ...
